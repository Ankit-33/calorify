# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = '/content/drive/MyDrive/data/train'
validation_dir = '/content/drive/MyDrive/data/validation'

# %%
# Importing necessary libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from PIL import Image

# Step 1: Prepare the Dataset Paths
train_dir = '/content/drive/MyDrive/data/train'
validation_dir = '/content/drive/MyDrive/data/validation'

# Step 2: Define Image Parameters
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 32

# Step 3: Data Augmentation for Training Data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

# Step 4: Data Preprocessing for Validation Data
validation_datagen = ImageDataGenerator(rescale=1./255)

# Step 5: Load Training and Validation Data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Step 6: Build the CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # 3 classes: french_fries, samosa, pizza
])

# Step 7: Compile the Model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.save("CNN_Model.h5")

# Step 8: Train the Model
EPOCHS = 70
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE
)

# Step 9: Function to Fetch Images Using Google Custom Search API
def fetch_images(query, num_images=1, api_key='YOUR_API_KEY', search_engine_id='YOUR_SEARCH_ENGINE_ID'):
    search_url = "https://www.googleapis.com/customsearch/v1"
    params = {
        'q': query,
        'cx': search_engine_id,
        'key': api_key,
        'searchType': 'image',
        'num': num_images
    }
    response = requests.get(search_url, params=params)
    results = response.json().get('items', [])
    image_urls = [item['link'] for item in results]
    return image_urls

# Step 10: Example Usage of the Fetch Images Function
api_key = 'AIzaSyAU_vOi6G0LeaPbShZst3REbr5C7KNoaTE'
search_engine_id = '62245e6dcba8145e3'
query = 'french fries'

# Fetch a single dynamic image for comparison
dynamic_image_url = fetch_images(query, num_images=1, api_key=api_key, search_engine_id=search_engine_id)[0]

# Step 11: Function to Download and Preprocess a Single Image
def download_and_preprocess_image(url, img_height=150, img_width=150):
    try:
        response = requests.get(url, timeout=5)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img = img.resize((img_width, img_height))
        img_array = np.array(img) / 255.0
        return img_array
    except Exception as e:
        print(f'Error downloading {url}: {e}')
        return None

# Step 12: Select a Specific Local Image
local_image_path = os.path.join(validation_dir, 'french_fries', '/content/51678.jpg')  # Example path
local_image = Image.open(local_image_path).convert('RGB')
local_image_resized = local_image.resize((IMG_WIDTH, IMG_HEIGHT))
local_image_array = np.array(local_image_resized) / 255.0

# Step 13: Download and Preprocess the Dynamic Image
dynamic_image_array = download_and_preprocess_image(dynamic_image_url)

# Step 14: Prepare Images for Model Prediction
X_compare = np.array([local_image_array, dynamic_image_array])

# Step 15: Predict Classes for Both Images
predictions = model.predict(X_compare)
predicted_class_indices = np.argmax(predictions, axis=1)
class_labels = list(train_generator.class_indices.keys())
predicted_classes = [class_labels[i] for i in predicted_class_indices]

# Step 16: Map Classes to Calorie Estimation
calorie_mapping = {
    'french_fries': 312,
    'samosa': 250,
    'pizza': 285
}
estimated_calories = [calorie_mapping.get(cls, 0) for cls in predicted_classes]

# Step 17: Display Local and Dynamic Image Comparison
plt.figure(figsize=(10, 5))

# Local image
plt.subplot(1, 2, 1)
plt.imshow(local_image_resized)
plt.title(f'Local Image: {predicted_classes[0]}\nEstimated Calories: {estimated_calories[0]}')

# Dynamic image
plt.subplot(1, 2, 2)
plt.imshow(dynamic_image_array)
plt.title(f'Dynamic Image: {predicted_classes[1]}\nEstimated Calories: {estimated_calories[1]}')

plt.show()
# Out:
# Found 2405 images belonging to 3 classes.
# Found 610 images belonging to 3 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/70
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.3540 - loss: 1.2209 - val_accuracy: 0.3339 - val_loss: 1.0970
# Epoch 2/70
#  1/75 ━━━━━━━━━━━━━━━━━━━━ 1:50 1s/step - accuracy: 0.3750 - loss: 1.0913
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.3750 - loss: 1.0913 - val_accuracy: 0.5000 - val_loss: 1.1062
# Epoch 3/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 175s 2s/step - accuracy: 0.3652 - loss: 1.0977 - val_accuracy: 0.3569 - val_loss: 1.0988
# Epoch 4/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3438 - loss: 1.1069 - val_accuracy: 0.5000 - val_loss: 1.1027
# Epoch 5/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.3475 - loss: 1.0966 - val_accuracy: 0.3717 - val_loss: 1.0891
# Epoch 6/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4375 - loss: 1.0860 - val_accuracy: 0.0000e+00 - val_loss: 1.0936
# Epoch 7/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.4268 - loss: 1.0787 - val_accuracy: 0.5938 - val_loss: 0.9567
# Epoch 8/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.5000 - loss: 0.9800 - val_accuracy: 0.5000 - val_loss: 0.9300
# Epoch 9/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.4603 - loss: 1.0241 - val_accuracy: 0.5987 - val_loss: 0.8870
# Epoch 10/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 747us/step - accuracy: 0.5000 - loss: 0.8437 - val_accuracy: 1.0000 - val_loss: 0.8879
# Epoch 11/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.5620 - loss: 0.8909 - val_accuracy: 0.7105 - val_loss: 0.7129
# Epoch 12/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - accuracy: 0.6875 - loss: 0.7363 - val_accuracy: 0.5000 - val_loss: 0.7731
# Epoch 13/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.5843 - loss: 0.8608 - val_accuracy: 0.7385 - val_loss: 0.6518
# Epoch 14/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 750us/step - accuracy: 0.5312 - loss: 0.9935 - val_accuracy: 0.5000 - val_loss: 0.7907
# Epoch 15/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.6489 - loss: 0.7771 - val_accuracy: 0.7039 - val_loss: 0.6888
# Epoch 16/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 715us/step - accuracy: 0.7812 - loss: 0.6751 - val_accuracy: 0.5000 - val_loss: 0.5450
# Epoch 17/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.7001 - loss: 0.7090 - val_accuracy: 0.7566 - val_loss: 0.5746
# Epoch 18/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 129ms/step - accuracy: 0.6875 - loss: 0.7062 - val_accuracy: 0.5000 - val_loss: 1.3406
# Epoch 19/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.6925 - loss: 0.6929 - val_accuracy: 0.7615 - val_loss: 0.5595
# Epoch 20/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 755us/step - accuracy: 0.8438 - loss: 0.5136 - val_accuracy: 0.0000e+00 - val_loss: 1.1918
# Epoch 21/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.7173 - loss: 0.6554 - val_accuracy: 0.7237 - val_loss: 0.7246
# Epoch 22/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7812 - loss: 0.4574 - val_accuracy: 1.0000 - val_loss: 0.0391
# Epoch 23/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.7267 - loss: 0.6565 - val_accuracy: 0.7895 - val_loss: 0.5115
# Epoch 24/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 773us/step - accuracy: 0.7812 - loss: 0.5618 - val_accuracy: 1.0000 - val_loss: 0.2285
# Epoch 25/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.7574 - loss: 0.5977 - val_accuracy: 0.7895 - val_loss: 0.5126
# Epoch 26/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.7812 - loss: 0.5177 - val_accuracy: 1.0000 - val_loss: 0.1406
# Epoch 27/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.7298 - loss: 0.5994 - val_accuracy: 0.8322 - val_loss: 0.4337
# Epoch 28/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - accuracy: 0.8125 - loss: 0.5549 - val_accuracy: 0.5000 - val_loss: 0.8328
# Epoch 29/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.7933 - loss: 0.5130 - val_accuracy: 0.8388 - val_loss: 0.4504
# Epoch 30/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - accuracy: 0.7812 - loss: 0.6100 - val_accuracy: 0.5000 - val_loss: 1.7939
# Epoch 31/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.7530 - loss: 0.5778 - val_accuracy: 0.8322 - val_loss: 0.4181
# Epoch 32/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - accuracy: 0.8125 - loss: 0.4596 - val_accuracy: 1.0000 - val_loss: 0.5814
# Epoch 33/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.7948 - loss: 0.5043 - val_accuracy: 0.7401 - val_loss: 0.6679
# Epoch 34/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 752us/step - accuracy: 0.7188 - loss: 0.7661 - val_accuracy: 1.0000 - val_loss: 0.0967
# Epoch 35/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.7975 - loss: 0.5304 - val_accuracy: 0.7484 - val_loss: 0.6329
# Epoch 36/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 836us/step - accuracy: 0.6875 - loss: 0.6664 - val_accuracy: 0.5000 - val_loss: 1.7736
# Epoch 37/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.7888 - loss: 0.5062 - val_accuracy: 0.6497 - val_loss: 0.7463
# Epoch 38/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 749us/step - accuracy: 0.6562 - loss: 0.6831 - val_accuracy: 1.0000 - val_loss: 0.4466
# Epoch 39/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.7868 - loss: 0.5012 - val_accuracy: 0.8553 - val_loss: 0.3842
# Epoch 40/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 735us/step - accuracy: 0.8125 - loss: 0.4725 - val_accuracy: 1.0000 - val_loss: 0.1228
# Epoch 41/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.7747 - loss: 0.5022 - val_accuracy: 0.8503 - val_loss: 0.4018
# Epoch 42/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step - accuracy: 0.8438 - loss: 0.3943 - val_accuracy: 1.0000 - val_loss: 0.2631
# Epoch 43/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.8236 - loss: 0.4404 - val_accuracy: 0.7878 - val_loss: 0.5238
# Epoch 44/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 906us/step - accuracy: 0.8438 - loss: 0.3197 - val_accuracy: 1.0000 - val_loss: 0.0572
# Epoch 45/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8079 - loss: 0.4706 - val_accuracy: 0.7961 - val_loss: 0.5649
# Epoch 46/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7500 - loss: 0.6133 - val_accuracy: 1.0000 - val_loss: 0.0347
# Epoch 47/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.7997 - loss: 0.4668 - val_accuracy: 0.8405 - val_loss: 0.4024
# Epoch 48/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 750us/step - accuracy: 0.7188 - loss: 0.5157 - val_accuracy: 0.5000 - val_loss: 1.0783
# Epoch 49/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8397 - loss: 0.4240 - val_accuracy: 0.8668 - val_loss: 0.3631
# Epoch 50/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - accuracy: 0.8438 - loss: 0.4650 - val_accuracy: 0.5000 - val_loss: 0.9520
# Epoch 51/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 190s 2s/step - accuracy: 0.8261 - loss: 0.4396 - val_accuracy: 0.8141 - val_loss: 0.4582
# Epoch 52/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 129ms/step - accuracy: 0.8125 - loss: 0.5037 - val_accuracy: 1.0000 - val_loss: 0.1923
# Epoch 53/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8476 - loss: 0.4116 - val_accuracy: 0.8322 - val_loss: 0.4451
# Epoch 54/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 867us/step - accuracy: 0.8438 - loss: 0.3774 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 55/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.8430 - loss: 0.3874 - val_accuracy: 0.8586 - val_loss: 0.3682
# Epoch 56/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - accuracy: 0.9062 - loss: 0.3727 - val_accuracy: 1.0000 - val_loss: 0.1319
# Epoch 57/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8601 - loss: 0.3648 - val_accuracy: 0.8618 - val_loss: 0.3637
# Epoch 58/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 772us/step - accuracy: 0.8438 - loss: 0.3870 - val_accuracy: 1.0000 - val_loss: 0.0779
# Epoch 59/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8572 - loss: 0.3651 - val_accuracy: 0.8586 - val_loss: 0.3950
# Epoch 60/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step - accuracy: 0.9062 - loss: 0.2340 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 61/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.8720 - loss: 0.3571 - val_accuracy: 0.8684 - val_loss: 0.3657
# Epoch 62/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 761us/step - accuracy: 0.9688 - loss: 0.1571 - val_accuracy: 1.0000 - val_loss: 0.0904
# Epoch 63/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.8658 - loss: 0.3578 - val_accuracy: 0.8717 - val_loss: 0.3457
# Epoch 64/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 797us/step - accuracy: 0.9688 - loss: 0.1795 - val_accuracy: 1.0000 - val_loss: 0.2108
# Epoch 65/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.8417 - loss: 0.3992 - val_accuracy: 0.8816 - val_loss: 0.3201
# Epoch 66/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8750 - loss: 0.2894 - val_accuracy: 0.5000 - val_loss: 1.1594
# Epoch 67/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.8635 - loss: 0.3563 - val_accuracy: 0.8931 - val_loss: 0.3048
# Epoch 68/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 826us/step - accuracy: 0.8750 - loss: 0.2771 - val_accuracy: 0.5000 - val_loss: 1.4545
# Epoch 69/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.8608 - loss: 0.3599 - val_accuracy: 0.8602 - val_loss: 0.4098
# Epoch 70/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 785us/step - accuracy: 0.7812 - loss: 0.4253 - val_accuracy: 1.0000 - val_loss: 0.0150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# Step 1: Make predictions on the validation set
validation_generator.reset()  # Reset the generator before predicting
predictions = model.predict(validation_generator, steps=validation_generator.samples // validation_generator.batch_size)
predicted_class_indices = np.argmax(predictions, axis=1)

# Step 2: Get true labels from the validation generator
true_class_indices = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

# Step 3: Generate classification report and accuracy
report = classification_report(true_class_indices[:len(predicted_class_indices)], predicted_class_indices, target_names=class_labels)
accuracy = accuracy_score(true_class_indices[:len(predicted_class_indices)], predicted_class_indices)

# Step 4: Print the results
print("Classification Report:\n", report)
print("Accuracy:", accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 599ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
# french_fries       0.33      0.28      0.30       200
#        pizza       0.33      0.32      0.33       210
#       samosa       0.31      0.36      0.33       198
#
#     accuracy                           0.32       608
#    macro avg       0.32      0.32      0.32       608
# weighted avg       0.32      0.32      0.32       608
#
# Accuracy: 0.3223684210526316
