# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = '/content/drive/MyDrive/data/train'
validation_dir = '/content/drive/MyDrive/data/validation'

# %%
# Importing necessary libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from PIL import Image

# Step 1: Prepare the Dataset Paths
train_dir = '/content/drive/MyDrive/data/train'
validation_dir = '/content/drive/MyDrive/data/validation'

# Step 2: Define Image Parameters
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 32

# Step 3: Data Augmentation for Training Data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

# Step 4: Data Preprocessing for Validation Data
validation_datagen = ImageDataGenerator(rescale=1./255)

# Step 5: Load Training and Validation Data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Step 6: Build the CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # 3 classes: french_fries, samosa, pizza
])

# Step 7: Compile the Model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.save("CNN_Model.h5")

# Step 8: Train the Model
EPOCHS = 70
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE
)

# Step 9: Function to Fetch Images Using Google Custom Search API
def fetch_images(query, num_images=1, api_key='YOUR_API_KEY', search_engine_id='YOUR_SEARCH_ENGINE_ID'):
    search_url = "https://www.googleapis.com/customsearch/v1"
    params = {
        'q': query,
        'cx': search_engine_id,
        'key': api_key,
        'searchType': 'image',
        'num': num_images
    }
    response = requests.get(search_url, params=params)
    results = response.json().get('items', [])
    image_urls = [item['link'] for item in results]
    return image_urls

# Step 10: Example Usage of the Fetch Images Function
api_key = 'AIzaSyAU_vOi6G0LeaPbShZst3REbr5C7KNoaTE'
search_engine_id = '62245e6dcba8145e3'
query = 'pizza'

# Fetch a single dynamic image for comparison
dynamic_image_url = fetch_images(query, num_images=1, api_key=api_key, search_engine_id=search_engine_id)[0]

# Step 11: Function to Download and Preprocess a Single Image
def download_and_preprocess_image(url, img_height=150, img_width=150):
    try:
        response = requests.get(url, timeout=5)
        img = Image.open(BytesIO(response.content)).convert('RGB')
        img = img.resize((img_width, img_height))
        img_array = np.array(img) / 255.0
        return img_array
    except Exception as e:
        print(f'Error downloading {url}: {e}')
        return None

# Step 12: Select a Specific Local Image
local_image_path = os.path.join(validation_dir, 'pizza', '/content/80750.jpg')  # Example path
local_image = Image.open(local_image_path).convert('RGB')
local_image_resized = local_image.resize((IMG_WIDTH, IMG_HEIGHT))
local_image_array = np.array(local_image_resized) / 255.0

# Step 13: Download and Preprocess the Dynamic Image
dynamic_image_array = download_and_preprocess_image(dynamic_image_url)

# Step 14: Prepare Images for Model Prediction
X_compare = np.array([local_image_array, dynamic_image_array])

# Step 15: Predict Classes for Both Images
predictions = model.predict(X_compare)
predicted_class_indices = np.argmax(predictions, axis=1)
class_labels = list(train_generator.class_indices.keys())
predicted_classes = [class_labels[i] for i in predicted_class_indices]

# Step 16: Map Classes to Calorie Estimation
calorie_mapping = {
    'french_fries': 312,
    'samosa': 250,
    'pizza': 285
}
estimated_calories = [calorie_mapping.get(cls, 0) for cls in predicted_classes]

# Step 17: Display Local and Dynamic Image Comparison
plt.figure(figsize=(10, 5))

# Local image
plt.subplot(1, 2, 1)
plt.imshow(local_image_resized)
plt.title(f'Local Image: {predicted_classes[0]}\nEstimated Calories: {estimated_calories[0]}')

# Dynamic image
plt.subplot(1, 2, 2)
plt.imshow(dynamic_image_array)
plt.title(f'Dynamic Image: {predicted_classes[1]}\nEstimated Calories: {estimated_calories[1]}')

plt.show()
# Out:
# Found 2405 images belonging to 3 classes.
# Found 610 images belonging to 3 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/70
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 175s 2s/step - accuracy: 0.3374 - loss: 1.6839 - val_accuracy: 0.3618 - val_loss: 1.0737
# Epoch 2/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 972us/step - accuracy: 0.3750 - loss: 1.1202 - val_accuracy: 0.0000e+00 - val_loss: 1.1026
# Epoch 3/70
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.4008 - loss: 1.0801 - val_accuracy: 0.4655 - val_loss: 1.0047
# Epoch 4/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 868us/step - accuracy: 0.5312 - loss: 1.0060 - val_accuracy: 0.5000 - val_loss: 0.7535
# Epoch 5/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.4675 - loss: 1.0170 - val_accuracy: 0.6003 - val_loss: 0.8351
# Epoch 6/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 735us/step - accuracy: 0.6562 - loss: 0.9052 - val_accuracy: 0.0000e+00 - val_loss: 1.0432
# Epoch 7/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.5443 - loss: 0.9003 - val_accuracy: 0.6645 - val_loss: 0.7885
# Epoch 8/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6250 - loss: 0.8410 - val_accuracy: 1.0000 - val_loss: 0.5873
# Epoch 9/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.5995 - loss: 0.8290 - val_accuracy: 0.6595 - val_loss: 0.6885
# Epoch 10/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 953us/step - accuracy: 0.5625 - loss: 0.8090 - val_accuracy: 1.0000 - val_loss: 0.0503
# Epoch 11/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.6278 - loss: 0.8019 - val_accuracy: 0.6102 - val_loss: 0.7914
# Epoch 12/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 742us/step - accuracy: 0.7812 - loss: 0.5485 - val_accuracy: 1.0000 - val_loss: 0.7409
# Epoch 13/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 193s 2s/step - accuracy: 0.6144 - loss: 0.8101 - val_accuracy: 0.6612 - val_loss: 0.6535
# Epoch 14/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.6875 - loss: 0.7424 - val_accuracy: 1.0000 - val_loss: 0.2116
# Epoch 15/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.6640 - loss: 0.7279 - val_accuracy: 0.7484 - val_loss: 0.5856
# Epoch 16/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 825us/step - accuracy: 0.7188 - loss: 0.7357 - val_accuracy: 0.0000e+00 - val_loss: 1.6164
# Epoch 17/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.6990 - loss: 0.6822 - val_accuracy: 0.7516 - val_loss: 0.5988
# Epoch 18/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.7188 - loss: 0.6418 - val_accuracy: 0.5000 - val_loss: 1.6470
# Epoch 19/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.6989 - loss: 0.7007 - val_accuracy: 0.7516 - val_loss: 0.6203
# Epoch 20/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step - accuracy: 0.8125 - loss: 0.5015 - val_accuracy: 0.0000e+00 - val_loss: 1.0573
# Epoch 21/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.7257 - loss: 0.6194 - val_accuracy: 0.8026 - val_loss: 0.5381
# Epoch 22/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6875 - loss: 0.6523 - val_accuracy: 0.0000e+00 - val_loss: 1.3676
# Epoch 23/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.7347 - loss: 0.6378 - val_accuracy: 0.7993 - val_loss: 0.4984
# Epoch 24/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7812 - loss: 0.4455 - val_accuracy: 1.0000 - val_loss: 0.2993
# Epoch 25/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.7559 - loss: 0.5799 - val_accuracy: 0.8158 - val_loss: 0.4805
# Epoch 26/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 715us/step - accuracy: 0.7188 - loss: 0.6095 - val_accuracy: 1.0000 - val_loss: 0.2791
# Epoch 27/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.7861 - loss: 0.5577 - val_accuracy: 0.7648 - val_loss: 0.6623
# Epoch 28/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - accuracy: 0.6562 - loss: 0.8139 - val_accuracy: 1.0000 - val_loss: 0.2520
# Epoch 29/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.7741 - loss: 0.5526 - val_accuracy: 0.8207 - val_loss: 0.4576
# Epoch 30/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 743us/step - accuracy: 0.9062 - loss: 0.3040 - val_accuracy: 1.0000 - val_loss: 0.0871
# Epoch 31/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.7925 - loss: 0.5143 - val_accuracy: 0.8273 - val_loss: 0.4616
# Epoch 32/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8438 - loss: 0.4397 - val_accuracy: 1.0000 - val_loss: 0.3776
# Epoch 33/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.7936 - loss: 0.5136 - val_accuracy: 0.7895 - val_loss: 0.5646
# Epoch 34/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8438 - loss: 0.4217 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 35/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - accuracy: 0.8003 - loss: 0.4939 - val_accuracy: 0.8043 - val_loss: 0.5169
# Epoch 36/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 979us/step - accuracy: 0.8125 - loss: 0.4673 - val_accuracy: 1.0000 - val_loss: 0.0836
# Epoch 37/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.8113 - loss: 0.4800 - val_accuracy: 0.8125 - val_loss: 0.4811
# Epoch 38/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 802us/step - accuracy: 0.7812 - loss: 0.5529 - val_accuracy: 1.0000 - val_loss: 0.0229
# Epoch 39/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - accuracy: 0.8054 - loss: 0.4846 - val_accuracy: 0.8520 - val_loss: 0.4174
# Epoch 40/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.7812 - loss: 0.4097 - val_accuracy: 1.0000 - val_loss: 0.2060
# Epoch 41/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - accuracy: 0.8075 - loss: 0.4662 - val_accuracy: 0.8240 - val_loss: 0.4314
# Epoch 42/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6875 - loss: 0.7037 - val_accuracy: 0.0000e+00 - val_loss: 1.2169
# Epoch 43/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.8226 - loss: 0.4443 - val_accuracy: 0.8438 - val_loss: 0.4047
# Epoch 44/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - accuracy: 0.9062 - loss: 0.2640 - val_accuracy: 1.0000 - val_loss: 0.1101
# Epoch 45/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.8145 - loss: 0.4707 - val_accuracy: 0.8684 - val_loss: 0.3763
# Epoch 46/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 759us/step - accuracy: 0.8125 - loss: 0.4998 - val_accuracy: 1.0000 - val_loss: 0.0690
# Epoch 47/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.8195 - loss: 0.4465 - val_accuracy: 0.8487 - val_loss: 0.3988
# Epoch 48/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 838us/step - accuracy: 0.8438 - loss: 0.3834 - val_accuracy: 1.0000 - val_loss: 0.0854
# Epoch 49/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.8473 - loss: 0.4056 - val_accuracy: 0.8109 - val_loss: 0.5766
# Epoch 50/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 746us/step - accuracy: 0.7812 - loss: 0.4941 - val_accuracy: 1.0000 - val_loss: 0.0788
# Epoch 51/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.8289 - loss: 0.4278 - val_accuracy: 0.8783 - val_loss: 0.3389
# Epoch 52/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.7188 - loss: 0.4203 - val_accuracy: 0.0000e+00 - val_loss: 1.3250
# Epoch 53/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - accuracy: 0.8453 - loss: 0.4115 - val_accuracy: 0.8635 - val_loss: 0.3784
# Epoch 54/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 753us/step - accuracy: 0.8125 - loss: 0.4174 - val_accuracy: 1.0000 - val_loss: 0.0435
# Epoch 55/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.8307 - loss: 0.4272 - val_accuracy: 0.8668 - val_loss: 0.3701
# Epoch 56/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 109ms/step - accuracy: 0.7812 - loss: 0.5396 - val_accuracy: 1.0000 - val_loss: 0.1169
# Epoch 57/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.8439 - loss: 0.4133 - val_accuracy: 0.8454 - val_loss: 0.4195
# Epoch 58/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 777us/step - accuracy: 0.9688 - loss: 0.1931 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 59/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.8438 - loss: 0.3872 - val_accuracy: 0.8536 - val_loss: 0.4207
# Epoch 60/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 739us/step - accuracy: 0.7812 - loss: 0.4881 - val_accuracy: 1.0000 - val_loss: 0.2304
# Epoch 61/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.8506 - loss: 0.3880 - val_accuracy: 0.8372 - val_loss: 0.4166
# Epoch 62/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 839us/step - accuracy: 0.8438 - loss: 0.3982 - val_accuracy: 1.0000 - val_loss: 0.1967
# Epoch 63/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.8420 - loss: 0.3976 - val_accuracy: 0.8470 - val_loss: 0.4232
# Epoch 64/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 841us/step - accuracy: 0.8438 - loss: 0.2969 - val_accuracy: 0.5000 - val_loss: 1.0924
# Epoch 65/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.8653 - loss: 0.3383 - val_accuracy: 0.8569 - val_loss: 0.4195
# Epoch 66/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - accuracy: 0.9062 - loss: 0.3178 - val_accuracy: 0.5000 - val_loss: 0.8609
# Epoch 67/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.8403 - loss: 0.4060 - val_accuracy: 0.8783 - val_loss: 0.3234
# Epoch 68/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 118ms/step - accuracy: 0.8750 - loss: 0.3217 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 69/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.8411 - loss: 0.3986 - val_accuracy: 0.8602 - val_loss: 0.4145
# Epoch 70/70
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8750 - loss: 0.2811 - val_accuracy: 0.5000 - val_loss: 0.9483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score

# Step 1: Make predictions on the validation set
validation_generator.reset()  # Reset the generator before predicting
predictions = model.predict(validation_generator, steps=validation_generator.samples // validation_generator.batch_size)
predicted_class_indices = np.argmax(predictions, axis=1)

# Step 2: Get true labels from the validation generator
true_class_indices = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())

# Step 3: Generate classification report and accuracy
report = classification_report(true_class_indices[:len(predicted_class_indices)], predicted_class_indices, target_names=class_labels)
accuracy = accuracy_score(true_class_indices[:len(predicted_class_indices)], predicted_class_indices)

# Step 4: Print the results
print("Classification Report:\n", report)
print("Accuracy:", accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 482ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
# french_fries       0.40      0.28      0.33       200
#        pizza       0.38      0.43      0.40       210
#       samosa       0.34      0.40      0.37       198
#
#     accuracy                           0.37       608
#    macro avg       0.37      0.37      0.37       608
# weighted avg       0.38      0.37      0.37       608
#
# Accuracy: 0.37006578947368424
